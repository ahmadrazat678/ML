# %%
import pandas as pd
import numpy as np

# Visualization
import seaborn as sns
import matplotlib.pyplot as plt

# ML
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
df = pd.read_csv("C:/Users/Laptop Links/Desktop/AI(ML&DL)/Datasets/diabetes.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.shape
# Out:
# (768, 9)

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.fillna('ffill', inplace=True)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
cols = ["Pregnancies", "Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI", "DiabetesPedigreeFunction","Age"]
plt.figure(figsize=(10,6))

for i, col in enumerate(cols, 1):
    plt.subplot(3,3,i)
    sns.boxplot(y=df[col])
    plt.title(col)

plt.tight_layout()
plt.show()

# %%
len(df)
# Out:
# 768

# %%
cols = ["Pregnancies", "Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI", "DiabetesPedigreeFunction","Age"]

df_clean = df.copy()

for col in cols:
    Q1 = df_clean[col].quantile(0.25)
    Q3 = df_clean[col].quantile(0.75)
    IQR = Q3-Q1

    lower_limit = Q1 - 0.5 * IQR
    upper_limit = Q3 + 0.5 * IQR

    df_clean = df_clean[(df_clean[col] >= lower_limit) & (df_clean[col] <= upper_limit)]
    
print("Rows after removing outliers:", len(df_clean))
# Out:
# Rows after removing outliers: 235

# %%
cols = ["Pregnancies", "Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI", "DiabetesPedigreeFunction","Age"]
plt.figure(figsize=(10,6))

for i, col in enumerate(cols, 1):
    plt.subplot(3,3,i)
    sns.boxplot(y=df_clean[col])
    plt.title(col)

plt.tight_layout()
plt.show()

# %%
df_clean["Outcome"].value_counts()
# Out:
# Outcome
# 0    191
# 1     44
# Name: count, dtype: int64

# %%
print('No diabetes', round(df_clean['Outcome'].value_counts()[0]/len(df_clean) * 100,2), '% of the dataset')
print('Has diabetes', round(df_clean['Outcome'].value_counts()[1]/len(df_clean) * 100,2), '% of the dataset')
# Out:
# No diabetes 81.28 % of the dataset
# Has diabetes 18.72 % of the dataset

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 6))
df_clean['Outcome'].value_counts().plot.pie(autopct='%1.1f%%', ax=ax[0])
ax[0].set_title('distribution')
ax[0].set_ylabel('')
sns.countplot(x='Outcome', data=df_clean, ax=ax[1])
ax[1].set_title('Outcome')
plt.show()

# %%
from sklearn.preprocessing import RobustScaler, StandardScaler
scaler = StandardScaler()

# %%
X = df_clean.drop("Outcome",axis=1)
y = df_clean["Outcome"]
X_train, X_test, y_train, y_test =train_test_split(X,y,test_size=0.20,random_state=2)

# %%
y.value_counts()
# Out:
# Outcome
# 0    191
# 1     44
# Name: count, dtype: int64

# %%
X_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 233            4      122             68              0        0  35.0
# 77             5       95             72             33        0  37.7
# 497            2       81             72             15       76  30.1
# 27             1       97             66             15      140  23.2
# 544            1       88             78             29       76  32.0
# ..           ...      ...            ...            ...      ...   ...
# 138            0      129             80              0        0  31.2
# 87             2      100             68             25       71  38.5
# 240            1       91             64             24        0  29.2
# 69             4      146             85             27      100  28.9
# 529            0      111             65              0        0  24.6
#
#      DiabetesPedigreeFunction  Age
# 233                     0.394   29
# 77                      0.370   27
# ...

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = model.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8297872340425532

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90        38
#            1       0.57      0.44      0.50         9
#
#     accuracy                           0.83        47
#    macro avg       0.72      0.68      0.70        47
# weighted avg       0.82      0.83      0.82        47

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)

plt.figure(figsize=(6,5))
sns.heatmap(cm,annot=True,fmt='d',cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# [[35  3]
#  [ 5  4]]

# %%
from sklearn.metrics import roc_auc_score, roc_curve

y_pred_proba = model.predict_proba(X_test)[:, 1]
auc = roc_auc_score(y_test, y_pred_proba)
print("AUC = %.3f" % auc)

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

# Plot ROC curve
plt.figure(figsize=(6, 5))
plt.plot(fpr, tpr, label=f'AUC = {auc:.3f}')
plt.plot([0, 1], [0, 1], '--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# AUC = 0.760

# %%
from imblearn.over_sampling import RandomOverSampler
oversample = RandomOverSampler(sampling_strategy='minority')
X_randomover, y_randomover = oversample.fit_resample(X_train, y_train)

# %%
# from imblearn.under_sampling import RandomUnderSampler
# undersample = RandomUnderSampler(sampling_strategy="majority")
# X_randomunder, y_randomunder = undersample.fit_resample(X_train, y_train)

# %%
y_randomover.value_counts()
# Out:
# Outcome
# 0    153
# 1    153
# Name: count, dtype: int64

# %%
model.fit(X_randomover, y_randomover)
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: %.3f%%" % (accuracy))
# Out:
# Accuracy: 0.638%

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# [[23 15]
#  [ 2  7]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.61      0.73        38
#            1       0.32      0.78      0.45         9
#
#     accuracy                           0.64        47
#    macro avg       0.62      0.69      0.59        47
# weighted avg       0.80      0.64      0.68        47

# %%
# Get predicted probabilities
y_pred_proba = model.predict_proba(X_test)[:, 1]
auc = roc_auc_score(y_test, y_pred_proba)
print("AUC = %.3f" % auc)

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

# Plot ROC curve
plt.figure(figsize=(6, 5))
plt.plot(fpr, tpr, label=f'AUC = {auc:.3f}')
plt.plot([0, 1], [0, 1], '--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# AUC = 0.743
